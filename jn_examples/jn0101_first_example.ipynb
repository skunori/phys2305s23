# %%
import numpy as np
import matplotlib.pyplot as plt

a=3+8
print(a)
# Out:
# 11

# %%
b=a*3.1415
c=a/3.1415
d=b+c
print("a=",a,"b=",b,"c=",c,"d=",d)
# Out:
# a= 11 b= 34.5565 c= 3.501512016552602 d= 38.0580120165526

# %%
p=np.pi
q=p/6.0
r=np.sin(p)
s=np.sin(q)
print("p=",p,"q=",q,"r=",r,"s",s)
# Out:
# p= 3.141592653589793 q= 0.5235987755982988 r= 1.2246467991473532e-16 s 0.49999999999999994

# %%
x=np.arange(0.0, 10.0, 0.01)
y=np.sin(x)
plt.plot(x,y)
plt.show()
